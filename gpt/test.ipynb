# %%
import torch

import torch.nn as nn

# %%
vocab_size = 1000
embedding_dim = 50

embedding = nn.Embedding(vocab_size,embedding_dim)

input_indices = torch.LongTensor([1,5,3,2])

embedded_output = embedding(input_indices)
embedded_output
# Out:
# tensor([[-0.5976, -0.0722,  1.0789, -1.2478, -0.2491,  0.6706, -0.4618,  0.5720,
#          -0.1234, -1.8026, -1.9477,  0.4311,  0.4513,  0.8996, -0.9238, -1.0677,
#           0.1284,  0.0298,  0.6855, -0.9273,  1.4418,  0.5684, -0.3889, -0.8927,
#           0.7959,  1.2065,  0.3792,  0.9545, -0.2737, -0.0044, -0.6766, -1.0632,
#           0.3872,  0.2988, -2.6306, -0.7261, -0.8262,  0.9574,  0.6406,  0.6726,
#          -0.3006,  0.5023,  0.2673, -0.2800,  0.2039, -0.2787, -1.6848, -0.1404,
#          -0.0130,  0.8204],
#         [ 0.7711, -0.5361, -0.3852, -1.6433, -0.6479, -0.9972,  0.6984,  1.3194,
#           0.6502,  1.1897,  1.3195, -0.6932,  0.4087,  0.8374, -0.8682, -0.5319,
#           0.2825, -0.1172,  0.1445, -0.8731,  1.3514, -0.7535, -0.1099, -0.0504,
#          -2.6234,  1.5261,  0.4686, -0.0594,  0.5552,  0.5836,  0.5994, -0.4686,
#           1.4424, -0.5681, -0.9947, -2.1687,  0.4929,  0.4512,  0.1311, -0.8333,
#          -0.6828, -0.2100,  0.0886,  0.4335, -0.6845,  0.6672, -0.2102,  0.9386,
#          -0.6385, -0.7956],
#         [ 0.0122,  0.8718,  0.9682, -1.4135,  1.7213, -1.2466,  0.5042, -0.5057,
#           0.6748, -1.1093,  1.2241,  0.3195, -0.3247,  0.0781,  1.3189, -0.9413,
#          -0.4767, -0.4615, -0.0257, -1.8810,  0.5241, -1.0031,  0.1453, -1.0097,
#          -0.3518,  1.8515,  0.2173,  0.3318,  0.0696,  0.9635,  0.2462, -1.0941,
#           0.8203,  0.0162,  0.3331,  0.8436,  0.0073, -0.4354,  0.3043,  2.0412,
#           0.1737,  0.3338,  0.9513,  0.6686,  1.0054, -1.1288,  0.6210,  0.2677,
#           0.2268,  2.3356],
#         [ 1.0816,  0.4491,  2.1804, -1.4382, -1.9090, -0.9515,  0.3579, -1.9162,
#           0.2080,  0.3647, -1.6510,  0.4222, -0.2098,  1.0384, -0.9856,  0.1421,
#           0.6473, -0.5415, -1.3171,  0.4343,  0.7963,  0.3340, -0.2251, -0.7718,
#           0.0896,  1.3797,  2.0081, -0.7490, -0.3052,  1.6549, -0.6470, -1.2120,
#           0.4309,  0.2281, -0.1700,  0.8601,  0.6575,  0.1006, -0.9688, -0.2659,
#          -0.7965,  0.3025, -0.8162,  0.4108, -0.2859, -0.4914,  0.4765, -0.9764,
#          -0.3534,  0.6929]], grad_fn=<EmbeddingBackward0>)
