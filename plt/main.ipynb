# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# x = [1,2,3,4,5]
# y =[1,4,9,16]

x =np.linspace(-100,100,40)

def fx(x):
    return x*x

fig,ax = plt.subplots(1,2,figsize=(8,4))

ax[0].plot(x,fx(x))
ax[1].plot()

# %%
def f(x):
    return x *4

def g(x):
    return x +4

def h(x):
    return x -3

d =f(g(h(3)))

d =g(h(3))

d = f(d)
d
# Out:
# 16
