# %%
import pandas
excel = pandas.read_csv("../recommand_system/shared_articles.csv")

# %%
sub = excel.sample(n=20, random_state=1)
sub.head(20)
# Out:
#        timestamp        eventType            contentId       authorPersonId  \
# 2953  1484321076   CONTENT SHARED -2034054811536485879  3609194402293569455
# 110   1459419865   CONTENT SHARED  4121807259563748287 -1443636648652872475
# 1043  1463750435   CONTENT SHARED -6859363289291329827  -492179582639058400
# 516   1461174897   CONTENT SHARED  -582471538642477927  3891637997717104548
# 340   1460459213  CONTENT REMOVED -4248528062574538011   301435144665447655
# 2608  1476970833   CONTENT SHARED  4859179221363512189 -8845298781299428018
# 1794  1468544041   CONTENT SHARED -8531951303518498324 -1616903969205976623
# 1477  1466541498   CONTENT SHARED -5395935973320542237  3609194402293569455
# 598   1461693696   CONTENT SHARED  2505379943041571189 -2979881261169775358
# 605   1461715957   CONTENT SHARED -8618420761918493321 -1032019229384696495
# 700   1462112019   CONTENT SHARED -2061825422128752184 -1032019229384696495
# ...

# %%
r =sub.groupby(['authorPersonId','lang'])

r.head()
# Out:
#        timestamp        eventType            contentId       authorPersonId  \
# 2953  1484321076   CONTENT SHARED -2034054811536485879  3609194402293569455
# 110   1459419865   CONTENT SHARED  4121807259563748287 -1443636648652872475
# 1043  1463750435   CONTENT SHARED -6859363289291329827  -492179582639058400
# 516   1461174897   CONTENT SHARED  -582471538642477927  3891637997717104548
# 340   1460459213  CONTENT REMOVED -4248528062574538011   301435144665447655
# 2608  1476970833   CONTENT SHARED  4859179221363512189 -8845298781299428018
# 1794  1468544041   CONTENT SHARED -8531951303518498324 -1616903969205976623
# 1477  1466541498   CONTENT SHARED -5395935973320542237  3609194402293569455
# 598   1461693696   CONTENT SHARED  2505379943041571189 -2979881261169775358
# 605   1461715957   CONTENT SHARED -8618420761918493321 -1032019229384696495
# 700   1462112019   CONTENT SHARED -2061825422128752184 -1032019229384696495
# ...

# %%
r.size()
# Out:
# authorPersonId        lang
# -8845298781299428018  en      1
# -8020832670974472349  en      1
# -2979881261169775358  en      1
# -2820994773540913369  pt      1
# -1616903969205976623  pt      1
# -1578287561410088674  en      1
# -1443636648652872475  en      3
# -1032019229384696495  en      3
# -492179582639058400   pt      1
#  301435144665447655   en      1
#  3217014177234377440  pt      1
#  3609194402293569455  en      2
#                       pt      1
#  3891637997717104548  en      1
#  5660542693104786364  en      1
# dtype: int64

# %%
r.count()
# Out:
#                            timestamp  eventType  contentId  authorSessionId  \
# lang authorPersonId
# en   -8845298781299428018          1          1          1                1
#      -8020832670974472349          1          1          1                1
#      -2979881261169775358          1          1          1                1
#      -1578287561410088674          1          1          1                1
#      -1443636648652872475          3          3          3                3
#      -1032019229384696495          3          3          3                3
#       301435144665447655           1          1          1                1
#       3609194402293569455          2          2          2                2
#       3891637997717104548          1          1          1                1
#       5660542693104786364          1          1          1                1
# pt   -2820994773540913369          1          1          1                1
# ...

# %%
r.sum()
# Out:
#         timestamp                                          eventType  \
# lang
# en    21950789492  CONTENT SHAREDCONTENT SHAREDCONTENT REMOVEDCON...
# pt     7360112405  CONTENT SHAREDCONTENT SHAREDCONTENT SHAREDCONT...
#
#                 contentId       authorPersonId      authorSessionId  \
# lang
# en   -8140914276996066418  6667480804817557784  1072775780807297742
# pt    5244845776853224111  1896130254141998503  8109558689445297219
#
#                                         authorUserAgent authorRegion  \
# lang
# en    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_0...           SP
# pt    Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...           SP
#
#      authorCountry                                        contentType  \
# lang
# en              BR  HTMLHTMLHTMLHTMLHTMLHTMLHTMLHTMLHTMLHTMLHTMLHT...
# pt              BR                               HTMLHTMLHTMLHTMLHTML
#
#                                                     url  \
# lang
# ...
