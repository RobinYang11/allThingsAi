# %%
import matplotlib.pyplot as plt
import numpy as np


# %matplotlib inline

x = list(range(0,10))
y = list(range(-10,0))

# plt.subplot(221)
plt.plot(x,y)
plt.plot(1,2,marker='o')
plt.plot()

a= np.arange(-4,4,0.5)
b= np.sin(a)

plt.plot(a,b)

plt.plot([1,2,3,4] ,[[1],[4],[9],[16]] ,'o')



plt.show()
