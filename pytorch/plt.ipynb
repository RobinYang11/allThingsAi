# %%
import matplotlib.pyplot as plt
import torch


x =torch.tensor([1,2,3,4])
y = torch.tensor([2,5,4,6])
plt.plot(x,y,'ro')

x1 = torch.tensor([[1],[2],[3],[4]])

print(x1)

plt.plot(x1,'bo')
# Out:
# tensor([[1],
#         [2],
#         [3],
#         [4]])
