# %% [markdown]
# ### pytorch Module 类
#   Module 类是所有神经网络的抽象类，我们自己的设计的神经网络必须继承这个类

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class MyModel(nn.Module):
    def __init__(self):
        super().__init__()
        # self.conv1 = nn.Conv2d(1,20,5)
        # self.conv2 = nn.Conv2d(20,20,5)
    
    def forward(self,x):
        
        return x + 1
        # x = F.relu(self.conv1(x))
        # return F.relu(self.conv2(x))

robin = MyModel()

res= robin(torch.tensor([1.,2.]))
print(res)
# Out:
# tensor([2., 3.])

# %% [markdown]
# ### Sequential  类的使用
# 该类可以把我们的层，以函数参数的形式，按顺序执行，可以减少网络代码的编写
#
# ## CIFAR10 模型代码结构
# ![image.png](https://img-blog.csdnimg.cn/dd8a0eb64fe24588982548278e54863e.png?x-oss-process=image/watermark,type_ZHJvaWRzYW5zZmFsbGJhY2s,shadow_50,text_Q1NETiBA6LevJuWuog==,size_20,color_FFFFFF,t_70,g_se,x_16)

# %%
class Robin(nn.Module):

    def __init__(self):
        super(Robin, self).__init__()

        # self.conv1 = nn.Conv2d(3, 32, 5, padding=2)
        # self.maxpool1 = nn.MaxPool2d(2)
        # self.conv2 = nn.Conv2d(32, 32, 5, padding=2)
        # self.maxpool2 = nn.MaxPool2d(2)
        # self.conv3 = nn.Conv2d(32, 64, 5, padding=2)
        # self.maxpool3 = nn.MaxPool2d(2)
        # self.flatten = nn.Flatten()
        # self.linear1 = nn.Linear(1024, 64)
        # self.linear2 = nn.Linear(64, 10)

        self.model1 = nn.Sequential(
            nn.Conv2d(3, 32, 5, padding=2),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 32, 5, padding=2),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 5, padding=2),
            nn.MaxPool2d(2),
            nn.Flatten(),
            nn.Linear(1024, 64),
            nn.Linear(64, 10)
        )

    def forward(self, x):
        # x = self.conv1(x)
        # x = self.maxpool1(x)
        # x = self.conv2(x)
        # x = self.maxpool2(x)
        # x = self.conv3(x)
        # x = self.maxpool3(x)
        # x = self.flatten(x)
        # x = self.linear1(x)
        # x = self.linear2(x)
        x =self.model1(x)
        return x


r = Robin()

input = torch.ones((64, 3, 32, 32))

ouput = r(input)
print(ouput)
# Out:
# tensor([[-0.0339,  0.1536,  0.0414, -0.1771,  0.0432,  0.0641,  0.1006, -0.0698,
#          -0.0578, -0.1317],
#         [-0.0339,  0.1536,  0.0414, -0.1771,  0.0432,  0.0641,  0.1006, -0.0698,
#          -0.0578, -0.1317],
#         [-0.0339,  0.1536,  0.0414, -0.1771,  0.0432,  0.0641,  0.1006, -0.0698,
#          -0.0578, -0.1317],
#         [-0.0339,  0.1536,  0.0414, -0.1771,  0.0432,  0.0641,  0.1006, -0.0698,
#          -0.0578, -0.1317],
#         [-0.0339,  0.1536,  0.0414, -0.1771,  0.0432,  0.0641,  0.1006, -0.0698,
#          -0.0578, -0.1317],
#         [-0.0339,  0.1536,  0.0414, -0.1771,  0.0432,  0.0641,  0.1006, -0.0698,
#          -0.0578, -0.1317],
#         [-0.0339,  0.1536,  0.0414, -0.1771,  0.0432,  0.0641,  0.1006, -0.0698,
#          -0.0578, -0.1317],
#         [-0.0339,  0.1536,  0.0414, -0.1771,  0.0432,  0.0641,  0.1006, -0.0698,
#          -0.0578, -0.1317],
#         [-0.0339,  0.1536,  0.0414, -0.1771,  0.0432,  0.0641,  0.1006, -0.0698,
# ...
